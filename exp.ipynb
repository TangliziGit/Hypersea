# %%
import matplotlib.pyplot as plt
import pickle as pkl

# %%
log = open('log/2020-08-06_00:36:12.log', 'r')
lines = log.readlines()

acc = [float(acc.split(' ')[-1]) for acc in lines if '[test] acc:' in acc]
state = [s[27:-19] for s in lines if 'to state' in s]

loss = [float(l[11:-1]) for l in lines if '--> [loss] ' in l]
print(loss)
print(lines)
# Out:
# [0.6746448278427124, -3.599851369857788, -5.559019565582275, -6.998650074005127]
# ['\n', '---------------------------------- [[#0 iteration]] ----------------------------------\n', '+---------+----------+--------------+-------------+--------------+-------------+-----+\n', '|   Type  | OfFilter | FilterHeight | FilterWidth | StrideHeight | StrideWidth | Acc |\n', '+---------+----------+--------------+-------------+--------------+-------------+-----+\n', '| current |   512    |      3       |      5      |      2       |      2      | 0.0 |\n', '|   best  |    0     |      0       |      0      |      0       |      0      | 0.0 |\n', '|  worst  |    0     |      0       |      0      |      0       |      0      | 1.0 |\n', '+---------+----------+--------------+-------------+--------------+-------------+-----+\n', '\n', "--> [step] from state tensor([512.,   3.,   5.,   2.,   2.], device='cuda:0')\n", '--> [step] action selected: idx4 act0 (stride_width_sub)\n', "--> [step] to state tensor([512.,   3.,   5.,   2.,   1.], device='cuda:0')\n", '--> [train] start\n', '[Epoch 3] loss: 4.829522252997474 acc: 0.6365\n', '[Epoch 7] loss: 3.3307979423981493 acc: 0.676\n', '[Epoch 11] loss: 2.5090737117220985 acc: 0.6852\n', '[Epoch 15] loss: 1.8374367820484865 acc: 0.7092\n', '[Epoch 19] loss: 1.3311048396636762 acc: 0.7078\n', '[Epoch 23] loss: 0.9973576002566101 acc: 0.7001\n', '[Epoch 27] loss: 0.7892201521321941 acc: 0.7013\n', '[Epoch 31] loss: 0.6565521887939452 acc: 0.7034\n', '[Epoch 35] loss: 0.5681356497328071 acc: 0.7049\n', '[Epoch 39] loss: 0.5019070559736255 acc: 0.7033\n', '[Epoch 43] loss: 0.45571929584150117 acc: 0.7101\n', '[Epoch 47] loss: 0.42131128849561716 acc: 0.6991\n', '[Epoch 51] loss: 0.3743398065352455 acc: 0.7065\n', '[Epoch 55] loss: 0.3581648576180534 acc: 0.6975\n', '[Epoch 59] loss: 0.3421525106386608 acc: 0.7087\n', '[Epoch 63] loss: 0.3284003833937637 acc: 0.7096\n', '[Epoch 67] loss: 0.30111066608563486 acc: 0.7063\n', '[Epoch 71] loss: 0.2871147104827187 acc: 0.7043\n', '--> [test] acc: 0.706\n', '--> [accuracy] finished 0.706\n', '--> [reward] 0.706\n', '+---------+----------+--------------+-------------+--------------+-------------+-------+\n', '|   Type  | OfFilter | FilterHeight | FilterWidth | StrideHeight | StrideWidth |  Acc  |\n', '+---------+----------+--------------+-------------+--------------+-------------+-------+\n', '| current |  512.0   |     3.0      |     5.0     |     2.0      |     1.0     | 0.706 |\n', '|   best  |  512.0   |     3.0      |     5.0     |     2.0      |     1.0     | 0.706 |\n', '|  worst  |  512.0   |     3.0      |     5.0     |     2.0      |     1.0     | 0.706 |\n', '+---------+----------+--------------+-------------+--------------+-------------+-------+\n', '\n', "--> [step] from state tensor([512.,   3.,   5.,   2.,   1.], device='cuda:0')\n", '--> [step] action selected: idx0 act1 (of_filter_add)\n', "--> [step] to state tensor([544.,   3.,   5.,   2.,   1.], device='cuda:0')\n", '--> [train] start\n', '[Epoch 3] loss: 4.838229559571542 acc: 0.6335\n', '[Epoch 7] loss: 3.345625877990137 acc: 0.6732\n', '[Epoch 11] loss: 2.503648301677021 acc: 0.6963\n', '[Epoch 15] loss: 1.8155256704906064 acc: 0.6991\n', '[Epoch 19] loss: 1.3028512469795355 acc: 0.6984\n', '[Epoch 23] loss: 0.9687389237496554 acc: 0.7033\n', '[Epoch 27] loss: 0.7679076952207119 acc: 0.7074\n', '[Epoch 31] loss: 0.6360220648586521 acc: 0.7006\n', '[Epoch 35] loss: 0.555539382007116 acc: 0.7029\n', '[Epoch 39] loss: 0.4860627930706648 acc: 0.7087\n', '[Epoch 43] loss: 0.4432695905256378 acc: 0.6991\n', '[Epoch 47] loss: 0.38948432325154464 acc: 0.698\n', '[Epoch 51] loss: 0.3746057708135537 acc: 0.705\n', '[Epoch 55] loss: 0.3434492154404178 acc: 0.7016\n', '[Epoch 59] loss: 0.32566266094841767 acc: 0.7022\n', '[Epoch 63] loss: 0.3109208296798646 acc: 0.7019\n', '[Epoch 67] loss: 0.29670553596075766 acc: 0.705\n', '[Epoch 71] loss: 0.2794478097394623 acc: 0.7077\n', '--> [test] acc: 0.71\n', '--> [accuracy] finished 0.71\n', '--> [reward] 0.0040000000000000036\n', '+--- ...

# %%
acc_ = [sum(acc[i:i+15])/len(acc[i:i+15]) for i in range(0, len(acc), 15)]

plt.figure(figsize=(15, 5))
plt.plot(acc)

# %%
acc_ = [sum(acc[i:i+15])/len(acc[i:i+15]) for i in range(0, len(acc), 15)]

plt.figure(figsize=(15, 5))
plt.plot(acc_)

# %%
plt.figure(figsize=(15, 5))
plt.plot(loss)
# for l in loss: print(l)

# %%
res = list(zip(range(len(acc)), acc, state))

# %%
res.sort(key=lambda x: x[1])
for r in res:
    print(r)
# Out:
# (56, 0.5696, '[448.,   1.,   6.,   3.,   1.]')
# (59, 0.5736, '[448.,   1.,   6.,   3.,   2.]')
# (57, 0.5769, '[448.,   1.,   6.,   3.,   2.]')
# (58, 0.5807, '[448.,   1.,   6.,   3.,   2.]')
# (44, 0.6531, '[448.,   2.,   6.,   3.,   1.]')
# (39, 0.6695, '[448.,   3.,   6.,   2.,   1.]')
# (38, 0.6742, '[480.,   3.,   6.,   2.,   1.]')
# (55, 0.6854, '[448.,   1.,   6.,   2.,   1.]')
# (37, 0.6874, '[480.,   3.,   7.,   2.,   1.]')
# (54, 0.6878, '[480.,   1.,   6.,   2.,   1.]')
# (65, 0.6878, '[480.,   1.,   6.,   2.,   2.]')
# (40, 0.6881, '[448.,   3.,   6.,   3.,   1.]')
# (63, 0.6897, '[448.,   1.,   6.,   2.,   2.]')
# (60, 0.6926, '[448.,   1.,   6.,   2.,   2.]')
# (52, 0.6932, '[448.,   1.,   6.,   2.,   2.]')
# (53, 0.6936, '[448.,   1.,   6.,   2.,   1.]')
# (62, 0.6967, '[448.,   1.,   6.,   2.,   2.]')
# (64, 0.6969, '[448.,   1.,   6.,   2.,   2.]')
# (43, 0.6988, '[448.,   3.,   6.,   3.,   1.]')
# (41, 0.6991, '[480.,   3.,   6.,   3.,   1.]')
# (42, 0.701, '[480.,   3.,   6.,   3.,   1.]')
# (61, 0.7022, '[448.,   1.,   6.,   2.,   2.]')
# (0, 0.706, '[512.,   3.,   5.,   2.,   1.]')
# (2, 0.707, '[512.,   3.,   5.,   2.,   1.]')
# (1, 0.71, '[544.,   3.,   5.,   2.,   1.]')
# (34, 0.7303, '[480.,   2.,   6.,   2.,   1.]')
# (45, 0.7323, '[448.,   2.,   6.,   2.,   1.]')
# (36, 0.7373, '[480.,   2.,   7.,   2.,   1.]')
# (35, 0.74, '[480.,   2.,   7.,   2.,   1.]')
# (28, 0.7476, '[480.,   4.,   5.,   1.,   2.]')
# (46, 0.7493, '[448.,   2.,   6.,   1.,   1.]')
# (24, 0.7507, '[480.,   4.,   6.,   1.,   1.]')
# (50, 0.7512, '[448.,   1.,   5.,   1.,   2.]')
# (33, 0.7514, '[480.,   2.,   6.,   1.,   1.]')
# (29, 0.7524, '[480.,   3.,   5.,   1.,   2.]')
# (23, 0.7543, '[480.,   4.,   6.,   1.,   1.]')
# (47, 0.7582, '[448.,   1.,   6.,   1.,   1.]')
# (51, 0.7609, '[448.,   1.,   6.,   1.,   2.]')
# (31, 0.7611, '[480.,   3.,   6.,   1.,   2.]')
# (11, 0.7612, '[544.,   4.,   4.,   1.,   1.]')
# (7, 0.7619, '[512.,   4.,   4.,   1.,   1.]')
# (32, 0.7628, '[480.,   3.,   6.,   1.,   1.]')
# (8, 0.7637, '[512.,   4.,   4.,   1.,   1.]')
# (12, 0.7702, '[544.,   4.,   4.,   1.,   1.]')
# (13, 0.7719, '[544.,   4.,   5.,   1.,   1.]')
# (30, 0.773, '[480.,   3.,   6.,   1.,   2.]')
# (48, 0.7735, '[448.,   1.,   5.,   1.,   1.]')
# (26, 0.7737, '[480.,   4.,   5.,   1.,   1.]')
# (49, 0.7746, '[448.,   1.,   5.,   1.,   1.]')
# (9, 0.7768, '[512.,   5.,   4.,   1.,   1.]')
# (10, 0.7771, '[544.,   5.,   4.,   1.,   1.]')
# (18, 0.7774, '[544.,   4.,   5.,   1.,   1.]')
# (22, 0.7778, '[480.,   4.,   5.,   1.,   1.]')
# (25, 0.7779, '[480.,   4.,   5.,   1.,   1.]')
# (6, 0.7785, '[512.,   4.,   5.,   1.,   1.]')
# (27, 0.7786, '[480.,   4.,   5.,   1.,   1.]')
# (21, 0.7799, '[512.,   4.,   5.,   1.,   1.]')
# (20, 0.7807, '[544.,   4.,   5.,   1.,   1.]')
# (4, 0.7818, '[512.,   4.,   5.,   1.,   1.]')
# (5, 0.7837, '[512.,   3.,   5.,   1.,   1.]')
# (17, 0.7856, '[544.,   3.,   5.,   1.,   1.]')
# (15, 0.786, '[544.,   3.,   5.,   1.,   1.]')
# (19, 0.7862, '[544.,   5.,   5.,   1.,   1.]')
# (3, 0.7863, '[512.,   3.,   5.,   1.,   1.]')
# (16, 0.7866, '[544.,   3.,   5.,   1.,   1.]')
# (14, 0.7909, '[544.,   3.,   5.,   1.,   1.]')

# %%
for r in res:
    print(r)
# Out:
# (0, 0.706, '[512.,   3.,   5.,   2.,   1.]')
# (1, 0.71, '[544.,   3.,   5.,   2.,   1.]')
# (2, 0.707, '[512.,   3.,   5.,   2.,   1.]')
# (3, 0.7863, '[512.,   3.,   5.,   1.,   1.]')
# (4, 0.7818, '[512.,   4.,   5.,   1.,   1.]')
# (5, 0.7837, '[512.,   3.,   5.,   1.,   1.]')
# (6, 0.7785, '[512.,   4.,   5.,   1.,   1.]')
# (7, 0.7619, '[512.,   4.,   4.,   1.,   1.]')
# (8, 0.7637, '[512.,   4.,   4.,   1.,   1.]')
# (9, 0.7768, '[512.,   5.,   4.,   1.,   1.]')
# (10, 0.7771, '[544.,   5.,   4.,   1.,   1.]')
# (11, 0.7612, '[544.,   4.,   4.,   1.,   1.]')
# (12, 0.7702, '[544.,   4.,   4.,   1.,   1.]')
# (13, 0.7719, '[544.,   4.,   5.,   1.,   1.]')
# (14, 0.7909, '[544.,   3.,   5.,   1.,   1.]')
# (15, 0.786, '[544.,   3.,   5.,   1.,   1.]')
# (16, 0.7866, '[544.,   3.,   5.,   1.,   1.]')
# (17, 0.7856, '[544.,   3.,   5.,   1.,   1.]')
# (18, 0.7774, '[544.,   4.,   5.,   1.,   1.]')
# (19, 0.7862, '[544.,   5.,   5.,   1.,   1.]')
# (20, 0.7807, '[544.,   4.,   5.,   1.,   1.]')
# (21, 0.7799, '[512.,   4.,   5.,   1.,   1.]')
# (22, 0.7778, '[480.,   4.,   5.,   1.,   1.]')
# (23, 0.7543, '[480.,   4.,   6.,   1.,   1.]')
# (24, 0.7507, '[480.,   4.,   6.,   1.,   1.]')
# (25, 0.7779, '[480.,   4.,   5.,   1.,   1.]')
# (26, 0.7737, '[480.,   4.,   5.,   1.,   1.]')
# (27, 0.7786, '[480.,   4.,   5.,   1.,   1.]')
# (28, 0.7476, '[480.,   4.,   5.,   1.,   2.]')
# (29, 0.7524, '[480.,   3.,   5.,   1.,   2.]')
# (30, 0.773, '[480.,   3.,   6.,   1.,   2.]')
# (31, 0.7611, '[480.,   3.,   6.,   1.,   2.]')
# (32, 0.7628, '[480.,   3.,   6.,   1.,   1.]')
# (33, 0.7514, '[480.,   2.,   6.,   1.,   1.]')
# (34, 0.7303, '[480.,   2.,   6.,   2.,   1.]')
# (35, 0.74, '[480.,   2.,   7.,   2.,   1.]')
# (36, 0.7373, '[480.,   2.,   7.,   2.,   1.]')
# (37, 0.6874, '[480.,   3.,   7.,   2.,   1.]')
# (38, 0.6742, '[480.,   3.,   6.,   2.,   1.]')
# (39, 0.6695, '[448.,   3.,   6.,   2.,   1.]')
# (40, 0.6881, '[448.,   3.,   6.,   3.,   1.]')
# (41, 0.6991, '[480.,   3.,   6.,   3.,   1.]')
# (42, 0.701, '[480.,   3.,   6.,   3.,   1.]')
# (43, 0.6988, '[448.,   3.,   6.,   3.,   1.]')
# (44, 0.6531, '[448.,   2.,   6.,   3.,   1.]')
# (45, 0.7323, '[448.,   2.,   6.,   2.,   1.]')
# (46, 0.7493, '[448.,   2.,   6.,   1.,   1.]')
# (47, 0.7582, '[448.,   1.,   6.,   1.,   1.]')
# (48, 0.7735, '[448.,   1.,   5.,   1.,   1.]')
# (49, 0.7746, '[448.,   1.,   5.,   1.,   1.]')
# (50, 0.7512, '[448.,   1.,   5.,   1.,   2.]')
# (51, 0.7609, '[448.,   1.,   6.,   1.,   2.]')
# (52, 0.6932, '[448.,   1.,   6.,   2.,   2.]')
# (53, 0.6936, '[448.,   1.,   6.,   2.,   1.]')
# (54, 0.6878, '[480.,   1.,   6.,   2.,   1.]')
# (55, 0.6854, '[448.,   1.,   6.,   2.,   1.]')
# (56, 0.5696, '[448.,   1.,   6.,   3.,   1.]')
# (57, 0.5769, '[448.,   1.,   6.,   3.,   2.]')
# (58, 0.5807, '[448.,   1.,   6.,   3.,   2.]')
# (59, 0.5736, '[448.,   1.,   6.,   3.,   2.]')
# (60, 0.6926, '[448.,   1.,   6.,   2.,   2.]')
# (61, 0.7022, '[448.,   1.,   6.,   2.,   2.]')
# (62, 0.6967, '[448.,   1.,   6.,   2.,   2.]')
# (63, 0.6897, '[448.,   1.,   6.,   2.,   2.]')
# (64, 0.6969, '[448.,   1.,   6.,   2.,   2.]')
# (65, 0.6878, '[480.,   1.,   6.,   2.,   2.]')
