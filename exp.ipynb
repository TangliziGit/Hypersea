# %%
import matplotlib.pyplot as plt
import pickle as pkl

# %%
log = open('log/2020-08-03_02:28:25.log', 'r')
lines = log.readlines()

acc = [float(acc.split(' ')[-1]) for acc in lines if '[test] acc:' in acc]
state = [s[27:-19] for s in lines if 'to state' in s]

loss = [float(l[11:-1]) for l in lines if '--> [loss] ' in l]

# %%
acc_ = [sum(acc[i:i+15])/len(acc[i:i+15]) for i in range(0, len(acc), 15)]

plt.figure(figsize=(15, 5))
plt.plot(acc)

# %%
acc_ = [sum(acc[i:i+15])/len(acc[i:i+15]) for i in range(0, len(acc), 15)]

plt.figure(figsize=(15, 5))
plt.plot(acc_)

# %%
plt.figure(figsize=(15, 5))
plt.plot(loss)
# for l in loss: print(l)

# %%
res = list(zip(range(len(acc)), acc, state))

# %%
res.sort(key=lambda x: x[1])
for r in res:
    print(r)
# Out:
# (45, 0.5258, '[448.,   1.,   3.,   3.,   2.]')
# (116, 0.5315, '[448.,   3.,   1.,   2.,   3.]')
# (78, 0.5322, '[448.,   3.,   1.,   2.,   3.]')
# (77, 0.5386, '[448.,   3.,   1.,   2.,   3.]')
# (115, 0.5731, '[448.,   3.,   1.,   3.,   3.]')
# (114, 0.5738, '[448.,   3.,   1.,   3.,   3.]')
# (76, 0.5772, '[448.,   4.,   1.,   2.,   3.]')
# (75, 0.5795, '[448.,   4.,   1.,   2.,   3.]')
# (112, 0.583, '[448.,   2.,   2.,   3.,   3.]')
# (117, 0.5847, '[448.,   4.,   1.,   2.,   3.]')
# (79, 0.589, '[448.,   4.,   1.,   2.,   3.]')
# (109, 0.5951, '[416.,   2.,   3.,   3.,   2.]')
# (106, 0.5978, '[448.,   2.,   3.,   3.,   2.]')
# (108, 0.6027, '[448.,   2.,   3.,   3.,   2.]')
# (46, 0.6045, '[448.,   2.,   3.,   3.,   2.]')
# (105, 0.6118, '[480.,   2.,   3.,   3.,   2.]')
# (104, 0.6181, '[480.,   2.,   3.,   3.,   3.]')
# (6, 0.6191, '[512.,   3.,   3.,   2.,   2.]')
# (74, 0.6206, '[448.,   4.,   1.,   1.,   3.]')
# (107, 0.6217, '[448.,   2.,   3.,   3.,   3.]')
# (171, 0.6217, '[416.,   2.,   4.,   3.,   2.]')
# (170, 0.6225, '[448.,   2.,   4.,   3.,   2.]')
# (7, 0.6278, '[544.,   3.,   3.,   2.,   2.]')
# (113, 0.6309, '[448.,   3.,   2.,   3.,   3.]')
# (22, 0.6356, '[544.,   2.,   4.,   3.,   3.]')
# (21, 0.6374, '[544.,   2.,   4.,   3.,   3.]')
# (5, 0.6382, '[512.,   3.,   3.,   2.,   3.]')
# (17, 0.6389, '[544.,   2.,   4.,   5.,   3.]')
# (110, 0.6396, '[416.,   2.,   2.,   3.,   2.]')
# (103, 0.6398, '[480.,   2.,   3.,   4.,   3.]')
# (102, 0.6403, '[480.,   2.,   3.,   4.,   3.]')
# (34, 0.6408, '[448.,   3.,   3.,   2.,   3.]')
# (161, 0.6425, '[448.,   2.,   5.,   3.,   2.]')
# (61, 0.6427, '[448.,   4.,   2.,   2.,   3.]')
# (111, 0.6427, '[448.,   2.,   2.,   3.,   2.]')
# (44, 0.6434, '[448.,   1.,   3.,   2.,   2.]')
# (8, 0.6443, '[544.,   3.,   3.,   2.,   3.]')
# (49, 0.6448, '[448.,   2.,   2.,   3.,   2.]')
# (169, 0.6495, '[448.,   2.,   5.,   3.,   2.]')
# (20, 0.652, '[544.,   2.,   5.,   3.,   3.]')
# (54, 0.6566, '[416.,   3.,   2.,   2.,   2.]')
# (52, 0.6569, '[416.,   3.,   1.,   3.,   2.]')
# (18, 0.6583, '[544.,   2.,   4.,   4.,   3.]')
# (80, 0.6603, '[448.,   4.,   1.,   2.,   2.]')
# (10, 0.6604, '[544.,   3.,   3.,   3.,   2.]')
# (166, 0.661, '[448.,   2.,   5.,   4.,   2.]')
# (19, 0.6612, '[544.,   2.,   5.,   4.,   3.]')
# (64, 0.6612, '[416.,   5.,   2.,   2.,   4.]')
# (101, 0.662, '[480.,   2.,   4.,   4.,   3.]')
# (65, 0.6628, '[384.,   5.,   2.,   2.,   4.]')
# (167, 0.6633, '[416.,   2.,   5.,   4.,   2.]')
# (43, 0.6636, '[448.,   1.,   4.,   2.,   2.]')
# (168, 0.6642, '[448.,   2.,   5.,   4.,   2.]')
# (72, 0.6643, '[448.,   4.,   1.,   2.,   2.]')
# (56, 0.6645, '[416.,   3.,   2.,   2.,   2.]')
# (84, 0.6647, '[480.,   4.,   3.,   2.,   2.]')
# (28, 0.6649, '[512.,   1.,   3.,   2.,   3.]')
# (60, 0.666, '[448.,   5.,   2.,   2.,   3.]')
# (118, 0.666, '[448.,   4.,   1.,   2.,   2.]')
# (4, 0.6668, '[512.,   3.,   4.,   2.,   3.]')
# (85, 0.6668, '[512.,   4.,   3.,   2.,   2.]')
# (68, 0.667, '[416.,   5.,   2.,   2.,   3.]')
# (1, 0.6689, '[544.,   3.,   5.,   2.,   3.]')
# (67, 0.6693, '[416.,   5.,   2.,   2.,   4.]')
# (69, 0.6694, '[448.,   5.,   2.,   2.,   3.]')
# (152, 0.6707, '[544.,   3.,   5.,   2.,   2.]')
# (62, 0.6709, '[448.,   5.,   2.,   2.,   3.]')
# (66, 0.6727, '[384.,   5.,   2.,   2.,   4.]')
# (3, 0.6733, '[544.,   3.,   4.,   2.,   3.]')
# (9, 0.6741, '[544.,   3.,   3.,   3.,   3.]')
# (38, 0.6761, '[448.,   1.,   4.,   2.,   3.]')
# (0, 0.6774, '[512.,   3.,   5.,   2.,   3.]')
# (151, 0.6775, '[544.,   3.,   5.,   2.,   2.]')
# (63, 0.6792, '[448.,   5.,   2.,   2.,   4.]')
# (2, 0.6793, '[544.,   3.,   5.,   2.,   3.]')
# (37, 0.6793, '[448.,   1.,   4.,   2.,   3.]')
# (11, 0.6795, '[544.,   3.,   3.,   3.,   3.]')
# (47, 0.6801, '[448.,   2.,   3.,   2.,   2.]')
# (71, 0.6811, '[448.,   5.,   1.,   2.,   2.]')
# (173, 0.6811, '[384.,   3.,   4.,   3.,   2.]')
# (39, 0.683, '[448.,   1.,   5.,   2.,   3.]')
# (172, 0.6835, '[416.,   3.,   4.,   3.,   2.]')
# (40, 0.6841, '[448.,   1.,   5.,   2.,   3.]')
# (202, 0.6848, '[448.,   4.,   3.,   4.,   2.]')
# (201, 0.6849, '[448.,   4.,   3.,   4.,   2.]')
# (153, 0.6866, '[544.,   3.,   6.,   2.,   2.]')
# (53, 0.6887, '[416.,   3.,   2.,   3.,   2.]')
# (50, 0.6892, '[448.,   3.,   2.,   3.,   2.]')
# (122, 0.6897, '[480.,   5.,   1.,   2.,   2.]')
# (12, 0.6898, '[544.,   3.,   4.,   3.,   3.]')
# (16, 0.6901, '[544.,   3.,   4.,   5.,   3.]')
# (41, 0.6901, '[448.,   1.,   5.,   2.,   3.]')
# (99, 0.6914, '[448.,   3.,   4.,   4.,   3.]')
# (96, 0.6918, '[480.,   4.,   3.,   4.,   3.]')
# (149, 0.692, '[544.,   3.,   4.,   2.,   1.]')
# (218, 0.6926, '[576.,   4.,   1.,   4.,   2.]')
# (164, 0.6929, '[448.,   3.,   5.,   3.,   2.]')
# (219, 0.693, '[576.,   4.,   1.,   4.,   2.]')
# (119, 0.6933, '[448.,   5.,   1.,   2.,   2.]')
# (51, 0.6935, '[416.,   3.,   2.,   3.,   2.]')
# (13, 0.6939, '[544.,   3.,   4.,   4.,   3.]')
# (162, 0.6946, '[448.,   3.,   5.,   3.,   2.]')
# (121, 0.6947, '[448.,   5.,   1.,   2.,   2.]')
# (100, 0.6949, '[480.,   3.,   4.,   4.,   3.]')
# (42, 0.6951, '[448.,   1.,   5.,   2.,   2.]')
# (217, 0.6956, '[576.,   4.,   1.,   4.,   2.]')
# (216, 0.6957, '[544.,   4.,   1.,   4.,   2.]')
# (86, 0.6959, '[512.,   4.,   4.,   2.,   2.]')
# (14, 0.696, '[512.,   3.,   4.,   4.,   3.]')
# (33, 0.6972, '[448.,   2.,   3.,   2.,   3.]')
# (97, 0.6973, '[448.,   4.,   3.,   4.,   3.]')
# (35, 0.6978, '[448.,   2.,   3.,   2.,   3.]')
# (30, 0.6984, '[512.,   2.,   3.,   2.,   4.]')
# (174, 0.6995, '[384.,   3.,   5.,   3.,   2.]')
# (15, 0.6999, '[544.,   3.,   4.,   4.,   3.]')
# (160, 0.701, '[448.,   3.,   5.,   3.,   2.]')
# (150, 0.7012, '[544.,   3.,   5.,   2.,   1.]')
# (159, 0.7014, '[480.,   3.,   5.,   3.,   2.]')
# (31, 0.7015, '[480.,   2.,   3.,   2.,   4.]')
# (58, 0.7015, '[448.,   4.,   2.,   2.,   2.]')
# (29, 0.7017, '[512.,   2.,   3.,   2.,   3.]')
# (32, 0.7017, '[448.,   2.,   3.,   2.,   4.]')
# (89, 0.7025, '[512.,   4.,   4.,   2.,   3.]')
# (26, 0.7032, '[544.,   2.,   3.,   2.,   3.]')
# (176, 0.7044, '[416.,   3.,   5.,   4.,   2.]')
# (148, 0.7048, '[544.,   3.,   3.,   2.,   1.]')
# (27, 0.7049, '[512.,   2.,   3.,   2.,   3.]')
# (175, 0.7049, '[384.,   3.,   5.,   4.,   2.]')
# (83, 0.7053, '[480.,   4.,   2.,   2.,   2.]')
# (82, 0.7063, '[480.,   4.,   2.,   2.,   2.]')
# (125, 0.7065, '[480.,   4.,   1.,   1.,   2.]')
# (81, 0.7066, '[448.,   4.,   2.,   2.,   2.]')
# (165, 0.7068, '[448.,   3.,   5.,   4.,   2.]')
# (55, 0.7075, '[416.,   4.,   2.,   2.,   2.]')
# (57, 0.7081, '[416.,   4.,   2.,   2.,   2.]')
# (154, 0.7085, '[544.,   3.,   6.,   3.,   2.]')
# (73, 0.7086, '[448.,   4.,   1.,   1.,   2.]')
# (156, 0.7103, '[512.,   3.,   6.,   3.,   2.]')
# (155, 0.7106, '[512.,   3.,   6.,   3.,   2.]')
# (158, 0.7108, '[480.,   3.,   6.,   3.,   2.]')
# (98, 0.7113, '[448.,   4.,   4.,   4.,   3.]')
# (95, 0.7126, '[480.,   4.,   4.,   4.,   3.]')
# (157, 0.715, '[512.,   3.,   6.,   3.,   2.]')
# (23, 0.7162, '[544.,   2.,   4.,   2.,   3.]')
# (93, 0.7175, '[512.,   4.,   4.,   4.,   3.]')
# (90, 0.7189, '[512.,   4.,   4.,   3.,   3.]')
# (94, 0.7197, '[480.,   4.,   4.,   4.,   3.]')
# (177, 0.7199, '[416.,   4.,   5.,   4.,   2.]')
# (123, 0.7203, '[480.,   5.,   1.,   1.,   2.]')
# (120, 0.7216, '[448.,   5.,   1.,   1.,   2.]')
# (36, 0.7238, '[448.,   2.,   4.,   2.,   3.]')
# (124, 0.7241, '[480.,   5.,   1.,   1.,   2.]')
# (48, 0.7242, '[448.,   2.,   2.,   2.,   2.]')
# (163, 0.7243, '[448.,   3.,   5.,   3.,   1.]')
# (182, 0.7244, '[416.,   4.,   6.,   4.,   1.]')
# (92, 0.7245, '[512.,   4.,   5.,   4.,   3.]')
# (183, 0.7246, '[416.,   4.,   6.,   4.,   1.]')
# (91, 0.7249, '[512.,   4.,   5.,   3.,   3.]')
# (214, 0.7261, '[544.,   4.,   2.,   3.,   2.]')
# (25, 0.7274, '[544.,   2.,   3.,   1.,   3.]')
# (184, 0.7274, '[416.,   4.,   6.,   4.,   2.]')
# (59, 0.7283, '[448.,   5.,   2.,   2.,   2.]')
# (178, 0.7283, '[416.,   4.,   6.,   4.,   2.]')
# (179, 0.7284, '[416.,   4.,   6.,   4.,   2.]')
# (180, 0.7284, '[416.,   4.,   6.,   4.,   2.]')
# (186, 0.7289, '[416.,   4.,   6.,   4.,   2.]')
# (187, 0.7294, '[416.,   4.,   5.,   4.,   2.]')
# (191, 0.7294, '[384.,   3.,   5.,   4.,   1.]')
# (215, 0.7296, '[544.,   4.,   2.,   4.,   2.]')
# (185, 0.7308, '[416.,   4.,   6.,   4.,   2.]')
# (70, 0.7335, '[448.,   5.,   2.,   2.,   2.]')
# (87, 0.7337, '[512.,   4.,   4.,   1.,   2.]')
# (192, 0.7354, '[416.,   3.,   5.,   4.,   1.]')
# (181, 0.7355, '[416.,   4.,   6.,   4.,   2.]')
# (223, 0.7368, '[576.,   4.,   1.,   4.,   1.]')
# (196, 0.7387, '[416.,   4.,   4.,   4.,   1.]')
# (211, 0.7392, '[544.,   4.,   2.,   4.,   1.]')
# (198, 0.7396, '[448.,   4.,   4.,   4.,   1.]')
# (229, 0.7397, '[576.,   4.,   1.,   3.,   1.]')
# (200, 0.7402, '[448.,   4.,   3.,   4.,   1.]')
# (144, 0.7406, '[512.,   4.,   3.,   2.,   1.]')
# (24, 0.7408, '[544.,   2.,   4.,   1.,   3.]')
# (194, 0.7422, '[416.,   4.,   4.,   4.,   1.]')
# (222, 0.7422, '[576.,   4.,   1.,   4.,   1.]')
# (203, 0.7424, '[448.,   4.,   3.,   4.,   1.]')
# (225, 0.7425, '[576.,   4.,   1.,   4.,   1.]')
# (227, 0.7429, '[576.,   4.,   1.,   4.,   1.]')
# (145, 0.7438, '[544.,   4.,   3.,   2.,   1.]')
# (228, 0.7443, '[576.,   4.,   1.,   3.,   1.]')
# (195, 0.7446, '[416.,   4.,   4.,   4.,   1.]')
# (220, 0.7453, '[576.,   4.,   1.,   4.,   1.]')
# (146, 0.7455, '[544.,   4.,   3.,   2.,   1.]')
# (147, 0.7458, '[544.,   4.,   3.,   2.,   1.]')
# (226, 0.7459, '[576.,   4.,   1.,   4.,   1.]')
# (224, 0.7466, '[576.,   4.,   1.,   4.,   1.]')
# (213, 0.747, '[544.,   4.,   2.,   3.,   1.]')
# (189, 0.7477, '[384.,   4.,   5.,   4.,   1.]')
# (193, 0.7477, '[416.,   4.,   5.,   4.,   1.]')
# (210, 0.7478, '[544.,   4.,   2.,   4.,   1.]')
# (212, 0.7478, '[544.,   4.,   2.,   4.,   1.]')
# (221, 0.748, '[576.,   4.,   1.,   4.,   1.]')
# (197, 0.7482, '[448.,   4.,   4.,   4.,   1.]')
# (207, 0.7482, '[512.,   4.,   3.,   4.,   1.]')
# (188, 0.7499, '[416.,   4.,   5.,   4.,   1.]')
# (199, 0.75, '[448.,   4.,   3.,   4.,   1.]')
# (205, 0.7512, '[448.,   4.,   3.,   4.,   1.]')
# (88, 0.7513, '[512.,   4.,   4.,   1.,   3.]')
# (204, 0.7534, '[448.,   4.,   3.,   4.,   1.]')
# (209, 0.7535, '[544.,   4.,   3.,   4.,   1.]')
# (190, 0.7564, '[384.,   4.,   5.,   4.,   1.]')
# (206, 0.7572, '[480.,   4.,   3.,   4.,   1.]')
# (208, 0.7593, '[512.,   4.,   3.,   4.,   1.]')
# (137, 0.7629, '[544.,   2.,   1.,   1.,   1.]')
# (127, 0.764, '[480.,   4.,   1.,   1.,   1.]')
# (126, 0.7656, '[480.,   4.,   1.,   1.,   1.]')
# (138, 0.7659, '[544.,   2.,   1.,   1.,   1.]')
# (128, 0.7695, '[480.,   3.,   1.,   1.,   1.]')
# (132, 0.7698, '[544.,   4.,   1.,   1.,   1.]')
# (131, 0.7712, '[512.,   4.,   1.,   1.,   1.]')
# (134, 0.7719, '[544.,   3.,   1.,   1.,   1.]')
# (139, 0.7723, '[544.,   3.,   1.,   1.,   1.]')
# (136, 0.7731, '[544.,   2.,   2.,   1.,   1.]')
# (135, 0.7738, '[544.,   3.,   2.,   1.,   1.]')
# (140, 0.7765, '[544.,   3.,   2.,   1.,   1.]')
# (141, 0.7775, '[512.,   3.,   2.,   1.,   1.]')
# (133, 0.7783, '[544.,   3.,   1.,   1.,   1.]')
# (129, 0.7787, '[480.,   3.,   1.,   1.,   1.]')
# (130, 0.7808, '[512.,   3.,   1.,   1.,   1.]')
# (143, 0.7847, '[512.,   4.,   3.,   1.,   1.]')
# (142, 0.7959, '[512.,   3.,   3.,   1.,   1.]')

# %%
for r in res:
    print(r)
# Out:
# (0, 0.6774, '[512.,   3.,   5.,   2.,   3.]')
# (1, 0.6689, '[544.,   3.,   5.,   2.,   3.]')
# (2, 0.6793, '[544.,   3.,   5.,   2.,   3.]')
# (3, 0.6733, '[544.,   3.,   4.,   2.,   3.]')
# (4, 0.6668, '[512.,   3.,   4.,   2.,   3.]')
# (5, 0.6382, '[512.,   3.,   3.,   2.,   3.]')
# (6, 0.6191, '[512.,   3.,   3.,   2.,   2.]')
# (7, 0.6278, '[544.,   3.,   3.,   2.,   2.]')
# (8, 0.6443, '[544.,   3.,   3.,   2.,   3.]')
# (9, 0.6741, '[544.,   3.,   3.,   3.,   3.]')
# (10, 0.6604, '[544.,   3.,   3.,   3.,   2.]')
# (11, 0.6795, '[544.,   3.,   3.,   3.,   3.]')
# (12, 0.6898, '[544.,   3.,   4.,   3.,   3.]')
# (13, 0.6939, '[544.,   3.,   4.,   4.,   3.]')
# (14, 0.696, '[512.,   3.,   4.,   4.,   3.]')
# (15, 0.6999, '[544.,   3.,   4.,   4.,   3.]')
# (16, 0.6901, '[544.,   3.,   4.,   5.,   3.]')
# (17, 0.6389, '[544.,   2.,   4.,   5.,   3.]')
# (18, 0.6583, '[544.,   2.,   4.,   4.,   3.]')
# (19, 0.6612, '[544.,   2.,   5.,   4.,   3.]')
# (20, 0.652, '[544.,   2.,   5.,   3.,   3.]')
# (21, 0.6374, '[544.,   2.,   4.,   3.,   3.]')
# (22, 0.6356, '[544.,   2.,   4.,   3.,   3.]')
# (23, 0.7162, '[544.,   2.,   4.,   2.,   3.]')
# (24, 0.7408, '[544.,   2.,   4.,   1.,   3.]')
# (25, 0.7274, '[544.,   2.,   3.,   1.,   3.]')
# (26, 0.7032, '[544.,   2.,   3.,   2.,   3.]')
# (27, 0.7049, '[512.,   2.,   3.,   2.,   3.]')
# (28, 0.6649, '[512.,   1.,   3.,   2.,   3.]')
# (29, 0.7017, '[512.,   2.,   3.,   2.,   3.]')
# (30, 0.6984, '[512.,   2.,   3.,   2.,   4.]')
# (31, 0.7015, '[480.,   2.,   3.,   2.,   4.]')
# (32, 0.7017, '[448.,   2.,   3.,   2.,   4.]')
# (33, 0.6972, '[448.,   2.,   3.,   2.,   3.]')
# (34, 0.6408, '[448.,   3.,   3.,   2.,   3.]')
# (35, 0.6978, '[448.,   2.,   3.,   2.,   3.]')
# (36, 0.7238, '[448.,   2.,   4.,   2.,   3.]')
# (37, 0.6793, '[448.,   1.,   4.,   2.,   3.]')
# (38, 0.6761, '[448.,   1.,   4.,   2.,   3.]')
# (39, 0.683, '[448.,   1.,   5.,   2.,   3.]')
# (40, 0.6841, '[448.,   1.,   5.,   2.,   3.]')
# (41, 0.6901, '[448.,   1.,   5.,   2.,   3.]')
# (42, 0.6951, '[448.,   1.,   5.,   2.,   2.]')
# (43, 0.6636, '[448.,   1.,   4.,   2.,   2.]')
# (44, 0.6434, '[448.,   1.,   3.,   2.,   2.]')
# (45, 0.5258, '[448.,   1.,   3.,   3.,   2.]')
# (46, 0.6045, '[448.,   2.,   3.,   3.,   2.]')
# (47, 0.6801, '[448.,   2.,   3.,   2.,   2.]')
# (48, 0.7242, '[448.,   2.,   2.,   2.,   2.]')
# (49, 0.6448, '[448.,   2.,   2.,   3.,   2.]')
# (50, 0.6892, '[448.,   3.,   2.,   3.,   2.]')
# (51, 0.6935, '[416.,   3.,   2.,   3.,   2.]')
# (52, 0.6569, '[416.,   3.,   1.,   3.,   2.]')
# (53, 0.6887, '[416.,   3.,   2.,   3.,   2.]')
# (54, 0.6566, '[416.,   3.,   2.,   2.,   2.]')
# (55, 0.7075, '[416.,   4.,   2.,   2.,   2.]')
# (56, 0.6645, '[416.,   3.,   2.,   2.,   2.]')
# (57, 0.7081, '[416.,   4.,   2.,   2.,   2.]')
# (58, 0.7015, '[448.,   4.,   2.,   2.,   2.]')
# (59, 0.7283, '[448.,   5.,   2.,   2.,   2.]')
# (60, 0.666, '[448.,   5.,   2.,   2.,   3.]')
# (61, 0.6427, '[448.,   4.,   2.,   2.,   3.]')
# (62, 0.6709, '[448.,   5.,   2.,   2.,   3.]')
# (63, 0.6792, '[448.,   5.,   2.,   2.,   4.]')
# (64, 0.6612, '[416.,   5.,   2.,   2.,   4.]')
# (65, 0.6628, '[384.,   5.,   2.,   2.,   4.]')
# (66, 0.6727, '[384.,   5.,   2.,   2.,   4.]')
# (67, 0.6693, '[416.,   5.,   2.,   2.,   4.]')
# (68, 0.667, '[416.,   5.,   2.,   2.,   3.]')
# (69, 0.6694, '[448.,   5.,   2.,   2.,   3.]')
# (70, 0.7335, '[448.,   5.,   2.,   2.,   2.]')
# (71, 0.6811, '[448.,   5.,   1.,   2.,   2.]')
# (72, 0.6643, '[448.,   4.,   1.,   2.,   2.]')
# (73, 0.7086, '[448.,   4.,   1.,   1.,   2.]')
# (74, 0.6206, '[448.,   4.,   1.,   1.,   3.]')
# (75, 0.5795, '[448.,   4.,   1.,   2.,   3.]')
# (76, 0.5772, '[448.,   4.,   1.,   2.,   3.]')
# (77, 0.5386, '[448.,   3.,   1.,   2.,   3.]')
# (78, 0.5322, '[448.,   3.,   1.,   2.,   3.]')
# (79, 0.589, '[448.,   4.,   1.,   2.,   3.]')
# (80, 0.6603, '[448.,   4.,   1.,   2.,   2.]')
# (81, 0.7066, '[448.,   4.,   2.,   2.,   2.]')
# (82, 0.7063, '[480.,   4.,   2.,   2.,   2.]')
# (83, 0.7053, '[480.,   4.,   2.,   2.,   2.]')
# (84, 0.6647, '[480.,   4.,   3.,   2.,   2.]')
# (85, 0.6668, '[512.,   4.,   3.,   2.,   2.]')
# (86, 0.6959, '[512.,   4.,   4.,   2.,   2.]')
# (87, 0.7337, '[512.,   4.,   4.,   1.,   2.]')
# (88, 0.7513, '[512.,   4.,   4.,   1.,   3.]')
# (89, 0.7025, '[512.,   4.,   4.,   2.,   3.]')
# (90, 0.7189, '[512.,   4.,   4.,   3.,   3.]')
# (91, 0.7249, '[512.,   4.,   5.,   3.,   3.]')
# (92, 0.7245, '[512.,   4.,   5.,   4.,   3.]')
# (93, 0.7175, '[512.,   4.,   4.,   4.,   3.]')
# (94, 0.7197, '[480.,   4.,   4.,   4.,   3.]')
# (95, 0.7126, '[480.,   4.,   4.,   4.,   3.]')
# (96, 0.6918, '[480.,   4.,   3.,   4.,   3.]')
# (97, 0.6973, '[448.,   4.,   3.,   4.,   3.]')
# (98, 0.7113, '[448.,   4.,   4.,   4.,   3.]')
# (99, 0.6914, '[448.,   3.,   4.,   4.,   3.]')
# (100, 0.6949, '[480.,   3.,   4.,   4.,   3.]')
# (101, 0.662, '[480.,   2.,   4.,   4.,   3.]')
# (102, 0.6403, '[480.,   2.,   3.,   4.,   3.]')
# (103, 0.6398, '[480.,   2.,   3.,   4.,   3.]')
# (104, 0.6181, '[480.,   2.,   3.,   3.,   3.]')
# (105, 0.6118, '[480.,   2.,   3.,   3.,   2.]')
# (106, 0.5978, '[448.,   2.,   3.,   3.,   2.]')
# (107, 0.6217, '[448.,   2.,   3.,   3.,   3.]')
# (108, 0.6027, '[448.,   2.,   3.,   3.,   2.]')
# (109, 0.5951, '[416.,   2.,   3.,   3.,   2.]')
# (110, 0.6396, '[416.,   2.,   2.,   3.,   2.]')
# (111, 0.6427, '[448.,   2.,   2.,   3.,   2.]')
# (112, 0.583, '[448.,   2.,   2.,   3.,   3.]')
# (113, 0.6309, '[448.,   3.,   2.,   3.,   3.]')
# (114, 0.5738, '[448.,   3.,   1.,   3.,   3.]')
# (115, 0.5731, '[448.,   3.,   1.,   3.,   3.]')
# (116, 0.5315, '[448.,   3.,   1.,   2.,   3.]')
# (117, 0.5847, '[448.,   4.,   1.,   2.,   3.]')
# (118, 0.666, '[448.,   4.,   1.,   2.,   2.]')
# (119, 0.6933, '[448.,   5.,   1.,   2.,   2.]')
# (120, 0.7216, '[448.,   5.,   1.,   1.,   2.]')
# (121, 0.6947, '[448.,   5.,   1.,   2.,   2.]')
# (122, 0.6897, '[480.,   5.,   1.,   2.,   2.]')
# (123, 0.7203, '[480.,   5.,   1.,   1.,   2.]')
# (124, 0.7241, '[480.,   5.,   1.,   1.,   2.]')
# (125, 0.7065, '[480.,   4.,   1.,   1.,   2.]')
# (126, 0.7656, '[480.,   4.,   1.,   1.,   1.]')
# (127, 0.764, '[480.,   4.,   1.,   1.,   1.]')
# (128, 0.7695, '[480.,   3.,   1.,   1.,   1.]')
# (129, 0.7787, '[480.,   3.,   1.,   1.,   1.]')
# (130, 0.7808, '[512.,   3.,   1.,   1.,   1.]')
# (131, 0.7712, '[512.,   4.,   1.,   1.,   1.]')
# (132, 0.7698, '[544.,   4.,   1.,   1.,   1.]')
# (133, 0.7783, '[544.,   3.,   1.,   1.,   1.]')
# (134, 0.7719, '[544.,   3.,   1.,   1.,   1.]')
# (135, 0.7738, '[544.,   3.,   2.,   1.,   1.]')
# (136, 0.7731, '[544.,   2.,   2.,   1.,   1.]')
# (137, 0.7629, '[544.,   2.,   1.,   1.,   1.]')
# (138, 0.7659, '[544.,   2.,   1.,   1.,   1.]')
# (139, 0.7723, '[544.,   3.,   1.,   1.,   1.]')
# (140, 0.7765, '[544.,   3.,   2.,   1.,   1.]')
# (141, 0.7775, '[512.,   3.,   2.,   1.,   1.]')
# (142, 0.7959, '[512.,   3.,   3.,   1.,   1.]')
# (143, 0.7847, '[512.,   4.,   3.,   1.,   1.]')
# (144, 0.7406, '[512.,   4.,   3.,   2.,   1.]')
# (145, 0.7438, '[544.,   4.,   3.,   2.,   1.]')
# (146, 0.7455, '[544.,   4.,   3.,   2.,   1.]')
# (147, 0.7458, '[544.,   4.,   3.,   2.,   1.]')
# (148, 0.7048, '[544.,   3.,   3.,   2.,   1.]')
# (149, 0.692, '[544.,   3.,   4.,   2.,   1.]')
# (150, 0.7012, '[544.,   3.,   5.,   2.,   1.]')
# (151, 0.6775, '[544.,   3.,   5.,   2.,   2.]')
# (152, 0.6707, '[544.,   3.,   5.,   2.,   2.]')
# (153, 0.6866, '[544.,   3.,   6.,   2.,   2.]')
# (154, 0.7085, '[544.,   3.,   6.,   3.,   2.]')
# (155, 0.7106, '[512.,   3.,   6.,   3.,   2.]')
# (156, 0.7103, '[512.,   3.,   6.,   3.,   2.]')
# (157, 0.715, '[512.,   3.,   6.,   3.,   2.]')
# (158, 0.7108, '[480.,   3.,   6.,   3.,   2.]')
# (159, 0.7014, '[480.,   3.,   5.,   3.,   2.]')
# (160, 0.701, '[448.,   3.,   5.,   3.,   2.]')
# (161, 0.6425, '[448.,   2.,   5.,   3.,   2.]')
# (162, 0.6946, '[448.,   3.,   5.,   3.,   2.]')
# (163, 0.7243, '[448.,   3.,   5.,   3.,   1.]')
# (164, 0.6929, '[448.,   3.,   5.,   3.,   2.]')
# (165, 0.7068, '[448.,   3.,   5.,   4.,   2.]')
# (166, 0.661, '[448.,   2.,   5.,   4.,   2.]')
# (167, 0.6633, '[416.,   2.,   5.,   4.,   2.]')
# (168, 0.6642, '[448.,   2.,   5.,   4.,   2.]')
# (169, 0.6495, '[448.,   2.,   5.,   3.,   2.]')
# (170, 0.6225, '[448.,   2.,   4.,   3.,   2.]')
# (171, 0.6217, '[416.,   2.,   4.,   3.,   2.]')
# (172, 0.6835, '[416.,   3.,   4.,   3.,   2.]')
# (173, 0.6811, '[384.,   3.,   4.,   3.,   2.]')
# (174, 0.6995, '[384.,   3.,   5.,   3.,   2.]')
# (175, 0.7049, '[384.,   3.,   5.,   4.,   2.]')
# (176, 0.7044, '[416.,   3.,   5.,   4.,   2.]')
# (177, 0.7199, '[416.,   4.,   5.,   4.,   2.]')
# (178, 0.7283, '[416.,   4.,   6.,   4.,   2.]')
# (179, 0.7284, '[416.,   4.,   6.,   4.,   2.]')
# (180, 0.7284, '[416.,   4.,   6.,   4.,   2.]')
# (181, 0.7355, '[416.,   4.,   6.,   4.,   2.]')
# (182, 0.7244, '[416.,   4.,   6.,   4.,   1.]')
# (183, 0.7246, '[416.,   4.,   6.,   4.,   1.]')
# (184, 0.7274, '[416.,   4.,   6.,   4.,   2.]')
# (185, 0.7308, '[416.,   4.,   6.,   4.,   2.]')
# (186, 0.7289, '[416.,   4.,   6.,   4.,   2.]')
# (187, 0.7294, '[416.,   4.,   5.,   4.,   2.]')
# (188, 0.7499, '[416.,   4.,   5.,   4.,   1.]')
# (189, 0.7477, '[384.,   4.,   5.,   4.,   1.]')
# (190, 0.7564, '[384.,   4.,   5.,   4.,   1.]')
# (191, 0.7294, '[384.,   3.,   5.,   4.,   1.]')
# (192, 0.7354, '[416.,   3.,   5.,   4.,   1.]')
# (193, 0.7477, '[416.,   4.,   5.,   4.,   1.]')
# (194, 0.7422, '[416.,   4.,   4.,   4.,   1.]')
# (195, 0.7446, '[416.,   4.,   4.,   4.,   1.]')
# (196, 0.7387, '[416.,   4.,   4.,   4.,   1.]')
# (197, 0.7482, '[448.,   4.,   4.,   4.,   1.]')
# (198, 0.7396, '[448.,   4.,   4.,   4.,   1.]')
# (199, 0.75, '[448.,   4.,   3.,   4.,   1.]')
# (200, 0.7402, '[448.,   4.,   3.,   4.,   1.]')
# (201, 0.6849, '[448.,   4.,   3.,   4.,   2.]')
# (202, 0.6848, '[448.,   4.,   3.,   4.,   2.]')
# (203, 0.7424, '[448.,   4.,   3.,   4.,   1.]')
# (204, 0.7534, '[448.,   4.,   3.,   4.,   1.]')
# (205, 0.7512, '[448.,   4.,   3.,   4.,   1.]')
# (206, 0.7572, '[480.,   4.,   3.,   4.,   1.]')
# (207, 0.7482, '[512.,   4.,   3.,   4.,   1.]')
# (208, 0.7593, '[512.,   4.,   3.,   4.,   1.]')
# (209, 0.7535, '[544.,   4.,   3.,   4.,   1.]')
# (210, 0.7478, '[544.,   4.,   2.,   4.,   1.]')
# (211, 0.7392, '[544.,   4.,   2.,   4.,   1.]')
# (212, 0.7478, '[544.,   4.,   2.,   4.,   1.]')
# (213, 0.747, '[544.,   4.,   2.,   3.,   1.]')
# (214, 0.7261, '[544.,   4.,   2.,   3.,   2.]')
# (215, 0.7296, '[544.,   4.,   2.,   4.,   2.]')
# (216, 0.6957, '[544.,   4.,   1.,   4.,   2.]')
# (217, 0.6956, '[576.,   4.,   1.,   4.,   2.]')
# (218, 0.6926, '[576.,   4.,   1.,   4.,   2.]')
# (219, 0.693, '[576.,   4.,   1.,   4.,   2.]')
# (220, 0.7453, '[576.,   4.,   1.,   4.,   1.]')
# (221, 0.748, '[576.,   4.,   1.,   4.,   1.]')
# (222, 0.7422, '[576.,   4.,   1.,   4.,   1.]')
# (223, 0.7368, '[576.,   4.,   1.,   4.,   1.]')
# (224, 0.7466, '[576.,   4.,   1.,   4.,   1.]')
# (225, 0.7425, '[576.,   4.,   1.,   4.,   1.]')
# (226, 0.7459, '[576.,   4.,   1.,   4.,   1.]')
# (227, 0.7429, '[576.,   4.,   1.,   4.,   1.]')
# (228, 0.7443, '[576.,   4.,   1.,   3.,   1.]')
# (229, 0.7397, '[576.,   4.,   1.,   3.,   1.]')
