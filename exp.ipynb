# %%
import matplotlib.pyplot as plt
import pickle as pkl

# %%
losses = pkl.load(open('losses.pkl', 'rb'))

plt.figure(figsize=(16, 16))
for idx, ls in enumerate(losses):
    plt.subplot(len(losses), 1, idx+1)
    plt.plot(ls)
